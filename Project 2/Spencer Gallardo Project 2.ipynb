# %% [markdown]
# # Spencergallardo.com Users

# %% [markdown]
# I have collected data on users who visit my website. I want to know where they are located by city, and if city is unavailable then by the state they live in.
#
# I Want to know:
#
# 1. What city has the most female users.
# 2. What city has the most male users.
# 3. What state has the largest number of users over the age of 30.
# 4. What state has the largest number of users under the age of 30.

# %%
import numpy as np
import pandas as pd
#set some pandas options controling output format
pd.set_option('display.notebook_repr_html',True) # output as flat text and not HTML
pd.set_option('display.max_rows', None) # this is the maximum number of rows we will display
pd.set_option('display.max_columns', None) # this is the maximum number of rows we will display

# read the csv into a dataframe, and force postal_code to be interpreted as a string.
users = pd.read_csv('data/sg_users.csv', dtype={'zip': str})

# Display the columns in the dataframe, and get a peak at how it's formatted
users.head()
# Out:
#       first    last  gender                email             address  \
# 0  Mathilda  Barton    Male     hitesre@nabju.bd      822 Nagaj Lane
# 1    Teresa  Foster  Female  ekzarmes@pefalez.om       1761 Kano Way
# 2     Keith  Norman  Female      enoufi@mufpa.hk   1734 Nadco Center
# 3      Vera  French  Female        si@genemhu.pr  1994 Juuvu Terrace
# 4    Nannie   Baker  Female       kipaweg@uto.et    809 Kegadu Plaza
#
#         city state    zip  age
# 0     Ijijne    TX  46333   19
# 1  Lidkegimi    VA  75671   36
# 2    Nadferi    KS  19335   50
# 3  Gefopobob    ME  62221   61
# 4    Kemuhla    AR  79723   56

# %%
# get rid of rows without a city, state, zip, and age
users.dropna(subset=['city', 'state', 'zip', 'age'], how='all', inplace=True)

# create a dataframe with the number users younger than 30 by State. Dropping NaN state values.
younger_users = users.dropna(subset=['state'], how='any') \
                [(users.dropna(subset=['state'], how='any').age <= 30)] \
                .groupby('state') \
                .state.count() \
                .reset_index(name='younger_30') \
                .sort_values(['state'], ascending=True)

# create a dataframe with the number users older than 30 by State. Dropping NaN state values.
older_users = users.dropna(subset=['state'], how='any') \
                [(users.dropna(subset=['state'], how='any').age >= 30)] \
                .groupby('state') \
                .state.count() \
                .reset_index(name='older_30') \
                .sort_values(['state'], ascending=True)

# join the two series into one dataframe
younger_users = younger_users.join(older_users.older_30)

# return the state with the users under than 30
younger_users.sort_values('younger_30', ascending=False).head(1)
# Out:
#   state  younger_30  older_30
# 4    FL           3         1

# %%
# return the state with users older than 30
younger_users.sort_values('older_30', ascending=False).head(1)
# Out:
#   state  younger_30  older_30
# 1    AZ           3         4

# %%
# create a dataframe with the number of female users by city
city_users = users.dropna(subset=['city'], how='any') \
                [(users.dropna(subset=['city'], how='any').gender == 'Female')] \
                .groupby(['city', 'state']) \
                .city.count() \
                .reset_index(name='female_count') \
                .sort_values(['city','state'], ascending=[True,True])

# create a dataframe with the number of male users by city
male_users = users.dropna(subset=['city'], how='any') \
                [(users.dropna(subset=['city'], how='any').gender == 'Male')] \
                .groupby(['city','state']) \
                .city.count() \
                .reset_index(name='male_count') \
                .sort_values(['city', 'state'], ascending=[True,True])
                
# join the two series into one dataframe
city_users = city_users.join(male_users.male_count)
city_users.male_count = male_users.male_count.astype(int)

# return the city with the most female users
city_users.sort_values('female_count', ascending=False).head(1)
# Out:
#         city state  female_count  male_count
# 0  Amilavuho    NH             1         1.0

# %%
# return the city with the most male users
city_users.sort_values('male_count', ascending=False).head(1)
# Out:
#         city state  female_count  male_count
# 0  Amilavuho    NH             1         1.0

# %%
Results

1. What city has the largest number of female users.
            Amilavuho, NH
2. What city has the largest number of male users.
            Amilavuho, NH
3. What state has the youngest users.
            Florida
4. What state has the largest number of male users.
            Arizona

# %% [markdown]
# ## Death Rates in the US
#
# 1. I will see all causes of death among Floridians.
# 2. I will filter data by grouping by year and leading cause

# %%
# read the csv into a dataframe, and set all "." to na values
dot = pd.read_csv('data/leading_cause_us.csv', na_values=['.'])

dot.sort_values(['Year', 'Cause Name'], ascending=[True, False]).head(10)
# Out:
#       Year                                     113 Cause Name  \
# 9427  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9444  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9461  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9478  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9495  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9512  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9529  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9546  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9563  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9580  1999  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                   Cause Name                 State  Deaths  \
# 9427  Unintentional injuries               Alabama    2313
# 9444  Unintentional injuries                Alaska     294
# 9461  Unintentional injuries               Arizona    2214
# 9478  Unintentional injuries              Arkansas    1287
# 9495  Unintentional injuries            California    9198
# 9512  Unintentional injuries              Colorado    1519
# 9529  Unintentional injuries           Connecticut    1034
# 9546  Unintentional injuries              Delaware     267
# 9563  Unintentional injuries  District of Columbia     161
# 9580  Unintentional injuries               Florida    5961
#
#       Age-adjusted Death Rate
# 9427                     52.2
# 9444                     55.9
# 9461                     44.8
# 9478                     47.6
# 9495                     28.7
# 9512                     39.0
# 9529                     29.3
# 9546                     35.3
# 9563                     28.4
# 9580                     35.7

# %%
# this line drops any rows with null for Year, Leading Cause, or Deaths.
dot.dropna(subset=['Year', 'Cause Name', 'Deaths'], how='any', inplace=True) 

# set the deaths column to integers so pandas interprets it numerically
dot.Deaths = dot.Deaths.astype(int)

# Sort the dataframe by Year and Leading Cause... which means total deaths for a leading cause.
dot.sort_values(['Year', 'Deaths'], ascending=[True, False], inplace=True)


# Filter the dataframe to show only deaths for White Non-Hispanic females.
f_wnh_deaths = dot[(dot.State== 'Florida')]
            
f_wnh_deaths.head(50)
# Out:
#       Year                                     113 Cause Name  \
# 230   1999                                         All Causes
# 4910  1999        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 2102  1999                      Malignant neoplasms (C00-C97)
# 7718  1999                 Cerebrovascular diseases (I60-I69)
# 3038  1999       Chronic lower respiratory diseases (J40-J47)
# 9580  1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 3974  1999                        Diabetes mellitus (E10-E14)
# 5846  1999                  Influenza and pneumonia (J09-J18)
# 1166  1999                          Alzheimer's disease (G30)
# 8654  1999  Intentional self-harm (suicide) (*U03,X60-X84,...
# 6783  1999  Nephritis, nephrotic syndrome and nephrosis (N...
# 229   2000                                         All Causes
# 4909  2000        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 2101  2000                      Malignant neoplasms (C00-C97)
# 7717  2000                 Cerebrovascular diseases (I60-I69)
# 3037  2000       Chronic lower respiratory diseases (J40-J47)
# 9579  2000  Accidents (unintentional injuries) (V01-X59,Y8...
# 3973  2000                        Diabetes mellitus (E10-E14)
# 5845  2000                  Influenza and pneumonia (J09-J18)
# 1165  2000                          Alzheimer's disease (G30)
# 8653  2000  Intentional self-harm (suicide) (*U03,X60-X84,...
# 6782  2000  Nephritis, nephrotic syndrome and nephrosis (N...
# 228   2001                                         All Causes
# 4908  2001        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 2100  2001                      Malignant neoplasms (C00-C97)
# 7716  2001                 Cerebrovascular diseases (I60-I69)
# 3036  2001       Chronic lower respiratory diseases (J40-J47)
# 9578  2001  Accidents (unintentional injuries) (V01-X59,Y8...
# 3972  2001                        Diabetes mellitus (E10-E14)
# 1164  2001                          Alzheimer's disease (G30)
# 5844  2001                  Influenza and pneumonia (J09-J18)
# 8652  2001  Intentional self-harm (suicide) (*U03,X60-X84,...
# 6781  2001  Nephritis, nephrotic syndrome and nephrosis (N...
# 227   2002                                         All Causes
# 4907  2002        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 2099  2002                      Malignant neoplasms (C00-C97)
# 7715  2002                 Cerebrovascular diseases (I60-I69)
# 3035  2002       Chronic lower respiratory diseases (J40-J47)
# 9577  2002  Accidents (unintentional injuries) (V01-X59,Y8...
# 3971  2002                        Diabetes mellitus (E10-E14)
# 1163  2002                          Alzheimer's disease (G30)
# 5843  2002                  Influenza and pneumonia (J09-J18)
# 8651  2002  Intentional self-harm (suicide) (*U03,X60-X84,...
# 6780  2002  Nephritis, nephrotic syndrome and nephrosis (N...
# 226   2003                                         All Causes
# 4906  2003        Diseases of heart (I00-I09,I11,I13,I20-I51)
# 2098  2003                      Malignant neoplasms (C00-C97)
# 7714  2003                 Cerebrovascular diseases (I60-I69)
# 3034  2003       Chronic lower respiratory diseases (J40-J47)
# 9576  2003  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                    Cause Name    State  Deaths  Age-adjusted Death Rate
# 230                All causes  Florida  163224                    812.8
# 4910            Heart disease  Florida   51434                    247.7
# 2102                   Cancer  Florida   38478                    190.6
# 7718                   Stroke  Florida   10560                     50.5
# 3038                     CLRD  Florida    9131                     43.1
# 9580   Unintentional injuries  Florida    5961                     35.7
# 3974                 Diabetes  Florida    4357                     21.5
# 5846  Influenza and pneumonia  Florida    3328                     16.1
# 1166      Alzheimer's disease  Florida    3059                     14.3
# 8654                  Suicide  Florida    2029                     12.2
# 6783           Kidney disease  Florida    1846                      8.9
# 229                All causes  Florida  164395                    807.8
# 4909            Heart disease  Florida   50336                    238.6
# 2101                   Cancer  Florida   39183                    191.6
# 7717                   Stroke  Florida   10532                     49.6
# 3037                     CLRD  Florida    8645                     40.3
# 9579   Unintentional injuries  Florida    6267                     37.3
# 3973                 Diabetes  Florida    4449                     21.6
# 5845  Influenza and pneumonia  Florida    3365                     16.0
# 1165      Alzheimer's disease  Florida    3265                     15.0
# 8653                  Suicide  Florida    2086                     12.4
# 6782           Kidney disease  Florida    1888                      8.9
# 228                All causes  Florida  167269                    806.1
# 4908            Heart disease  Florida   50629                    236.0
# 2100                   Cancer  Florida   39090                    187.4
# 7716                   Stroke  Florida   10414                     48.2
# 3036                     CLRD  Florida    8954                     41.2
# 9578   Unintentional injuries  Florida    6969                     40.5
# 3972                 Diabetes  Florida    4631                     22.1
# 1164      Alzheimer's disease  Florida    3643                     16.4
# 5844  Influenza and pneumonia  Florida    3317                     15.5
# 8652                  Suicide  Florida    2314                     13.5
# 6781           Kidney disease  Florida    2172                     10.1
# 227                All causes  Florida  167814                    796.2
# 4907            Heart disease  Florida   49235                    226.1
# 2099                   Cancer  Florida   39140                    183.8
# 7715                   Stroke  Florida   10269                     46.9
# 3035                     CLRD  Florida    9062                     40.9
# 9577   Unintentional injuries  Florida    7396                     42.0
# 3971                 Diabetes  Florida    4583                     21.5
# 1163      Alzheimer's disease  Florida    4052                     18.1
# 5843  Influenza and pneumonia  Florida    3290                     15.1
# 8651                  Suicide  Florida    2338                     13.3
# 6780           Kidney disease  Florida    2201                     10.2
# 226                All causes  Florida  168657                    786.7
# 4906            Heart disease  Florida   48141                    217.3
# 2098                   Cancer  Florida   39404                    181.7
# 7714                   Stroke  Florida    9899                     44.4
# 3034                     CLRD  Florida    9087                     40.4
# 9576   Unintentional injuries  Florida    7919                     44.2

# %%
leading_cause_by_year = dot.groupby(['Year', 'Cause Name'], \
                        as_index=False)['Deaths'].sum()

leading_cause_by_year.sort_values(['Year', 'Deaths'], ascending=[True,False])
# Out:
#      Year               Cause Name   Deaths
# 0    1999               All causes  4782798
# 5    1999            Heart disease  1450384
# 3    1999                   Cancer  1099676
# 8    1999                   Stroke   334732
# 2    1999                     CLRD   248362
# 10   1999   Unintentional injuries   195720
# 4    1999                 Diabetes   136798
# 6    1999  Influenza and pneumonia   127460
# 1    1999      Alzheimer's disease    89072
# 7    1999           Kidney disease    71050
# 9    1999                  Suicide    58398
# 11   2000               All causes  4806702
# 16   2000            Heart disease  1421520
# 14   2000                   Cancer  1106182
# 19   2000                   Stroke   335322
# 13   2000                     CLRD   244018
# 21   2000   Unintentional injuries   195800
# 15   2000                 Diabetes   138602
# 17   2000  Influenza and pneumonia   130626
# 12   2000      Alzheimer's disease    99116
# 18   2000           Kidney disease    74502
# 20   2000                  Suicide    58700
# 22   2001               All causes  4832850
# 27   2001            Heart disease  1400284
# 25   2001                   Cancer  1107536
# 30   2001                   Stroke   327076
# 24   2001                     CLRD   246026
# 32   2001   Unintentional injuries   203074
# 26   2001                 Diabetes   142744
# 28   2001  Influenza and pneumonia   124068
# 23   2001      Alzheimer's disease   107704
# 29   2001           Kidney disease    78960
# 31   2001                  Suicide    61244
# 33   2002               All causes  4886774
# 38   2002            Heart disease  1393894
# 36   2002                   Cancer  1114542
# 41   2002                   Stroke   325344
# 35   2002                     CLRD   249632
# 43   2002   Unintentional injuries   213484
# 37   2002                 Diabetes   146498
# 39   2002  Influenza and pneumonia   131362
# 34   2002      Alzheimer's disease   117732
# 40   2002           Kidney disease    81948
# 42   2002                  Suicide    63310
# 44   2003               All causes  4896576
# 49   2003            Heart disease  1370178
# 47   2003                   Cancer  1113804
# 52   2003                   Stroke   315378
# 46   2003                     CLRD   252764
# 54   2003   Unintentional injuries   218554
# 48   2003                 Diabetes   148438
# 50   2003  Influenza and pneumonia   130326
# 45   2003      Alzheimer's disease   126914
# 51   2003           Kidney disease    84906
# 53   2003                  Suicide    62968
# 55   2004               All causes  4795230
# 60   2004            Heart disease  1304972
# 58   2004                   Cancer  1107776
# 63   2004                   Stroke   300148
# 57   2004                     CLRD   243974
# 65   2004   Unintentional injuries   224024
# 59   2004                 Diabetes   146276
# 56   2004      Alzheimer's disease   131930
# 61   2004  Influenza and pneumonia   119328
# 62   2004           Kidney disease    84960
# 64   2004                  Suicide    64878
# 66   2005               All causes  4896034
# 71   2005            Heart disease  1304182
# 69   2005                   Cancer  1118624
# 74   2005                   Stroke   287158
# 68   2005                     CLRD   261866
# 76   2005   Unintentional injuries   235618
# 70   2005                 Diabetes   150238
# 67   2005      Alzheimer's disease   143198
# 72   2005  Influenza and pneumonia   126002
# 73   2005           Kidney disease    87802
# 75   2005                  Suicide    65274
# 77   2006               All causes  4852528
# 82   2006            Heart disease  1263272
# 80   2006                   Cancer  1119776
# 85   2006                   Stroke   274238
# 79   2006                     CLRD   249166
# 87   2006   Unintentional injuries   243198
# 81   2006                 Diabetes   144898
# 78   2006      Alzheimer's disease   144864
# 83   2006  Influenza and pneumonia   112652
# 84   2006           Kidney disease    90688
# 86   2006                  Suicide    66600
# 88   2007               All causes  4847424
# 93   2007            Heart disease  1232134
# 91   2007                   Cancer  1125750
# 96   2007                   Stroke   271904
# 90   2007                     CLRD   255848
# 98   2007   Unintentional injuries   247412
# 89   2007      Alzheimer's disease   149264
# 92   2007                 Diabetes   142764
# 94   2007  Influenza and pneumonia   105434
# 95   2007           Kidney disease    92896
# 97   2007                  Suicide    69196
# 99   2008               All causes  4943968
# 104  2008            Heart disease  1233656
# 102  2008                   Cancer  1130938
# 101  2008                     CLRD   282180
# 107  2008                   Stroke   268296
# 109  2008   Unintentional injuries   243804
# 100  2008      Alzheimer's disease   164870
# 103  2008                 Diabetes   141106
# 105  2008  Influenza and pneumonia   112568
# 106  2008           Kidney disease    96474
# 108  2008                  Suicide    72070
# 110  2009               All causes  4874326
# 115  2009            Heart disease  1198826
# 113  2009                   Cancer  1135256
# 112  2009                     CLRD   274706
# 118  2009                   Stroke   257684
# 120  2009   Unintentional injuries   236042
# 111  2009      Alzheimer's disease   158006
# 114  2009                 Diabetes   137410
# 116  2009  Influenza and pneumonia   107384
# 117  2009           Kidney disease    97870
# 119  2009                  Suicide    73818
# 121  2010               All causes  4936870
# 126  2010            Heart disease  1195378
# 124  2010                   Cancer  1149486
# 123  2010                     CLRD   276160
# 129  2010                   Stroke   258952
# 131  2010   Unintentional injuries   241718
# 122  2010      Alzheimer's disease   166988
# 125  2010                 Diabetes   138142
# 128  2010           Kidney disease   100952
# 127  2010  Influenza and pneumonia   100194
# 130  2010                  Suicide    76728
# 132  2011               All causes  5030916
# 137  2011            Heart disease  1193154
# 135  2011                   Cancer  1153382
# 134  2011                     CLRD   285886
# 140  2011                   Stroke   257864
# 142  2011   Unintentional injuries   252876
# 133  2011      Alzheimer's disease   169948
# 136  2011                 Diabetes   147662
# 138  2011  Influenza and pneumonia   107652
# 139  2011           Kidney disease    91182
# 141  2011                  Suicide    79036
# 143  2012               All causes  5086558
# 148  2012            Heart disease  1199422
# 146  2012                   Cancer  1165246
# 145  2012                     CLRD   286978
# 151  2012                   Stroke   257092
# 153  2012   Unintentional injuries   255584
# 144  2012      Alzheimer's disease   167274
# 147  2012                 Diabetes   147864
# 149  2012  Influenza and pneumonia   101272
# 150  2012           Kidney disease    91244
# 152  2012                  Suicide    81200
# 154  2013               All causes  5193986
# 159  2013            Heart disease  1222210
# 157  2013                   Cancer  1169762
# 156  2013                     CLRD   298410
# 164  2013   Unintentional injuries   261114
# 162  2013                   Stroke   257956
# 155  2013      Alzheimer's disease   169534
# 158  2013                 Diabetes   151156
# 160  2013  Influenza and pneumonia   113958
# 161  2013           Kidney disease    94224
# 163  2013                  Suicide    82298
# 165  2014               All causes  5252836
# 170  2014            Heart disease  1228696
# 168  2014                   Cancer  1183400
# 167  2014                     CLRD   294202
# 175  2014   Unintentional injuries   271856
# 173  2014                   Stroke   266206
# 166  2014      Alzheimer's disease   187082
# 169  2014                 Diabetes   152976
# 171  2014  Influenza and pneumonia   110454
# 172  2014           Kidney disease    96292
# 174  2014                  Suicide    85652
# 176  2015               All causes  5425260
# 181  2015            Heart disease  1267684
# 179  2015                   Cancer  1191860
# 178  2015                     CLRD   310082
# 186  2015   Unintentional injuries   293142
# 184  2015                   Stroke   280646
# 177  2015      Alzheimer's disease   221122
# 180  2015                 Diabetes   159070
# 182  2015  Influenza and pneumonia   114124
# 183  2015           Kidney disease    99918
# 185  2015                  Suicide    88386
# 187  2016               All causes  5063723
# 192  2016            Heart disease  1270520
# 190  2016                   Cancer  1196076
# 197  2016   Unintentional injuries   322748
# 189  2016                     CLRD   309192
# 195  2016                   Stroke   284284
# 188  2016      Alzheimer's disease   232206
# 191  2016                 Diabetes   160116
# 193  2016  Influenza and pneumonia   103074
# 194  2016           Kidney disease   100092
# 196  2016                  Suicide    89930

# %% [markdown]
# ## Traffic Violations

# %% [markdown]
# 1. I will analyze the data by finding out which type of car has the most violations
# 2. Which state besides Maryland has the highest violations
# 3. Which violation is most popular

# %%
# dot = pd.read_csv('data/traffic_violations', na_values=['.'])
traffic_full = pd.read_csv('data/traffic_violations.csv', dtype={'Year': str})
traffic_full = traffic_full.rename(columns={'Driver State': 'driver_state', \
                          'Violation Type': 'violation_type',})

# %%
# create a series that contains the year, make, and model in one string
tempdf = traffic_full['Year'].astype(str) + ' ' + traffic_full['Make'] + ' ' + traffic_full['Model']

# create a dataframe that contains a subset of the traffic data
traffic = traffic_full[['Fatal', 'driver_state', 'violation_type']].copy()
traffic['ymm'] = tempdf # add the year/make/model column to the dataframe
traffic.head() # display the new dataframe
# Out:
#   Fatal driver_state violation_type                  ymm
# 0    No           MD       Citation         2008 FORD 4S
# 1    No           VA       Citation  2001 TOYOTA COROLLA
# 2    No           MD       Citation    2001 HONDA ACCORD
# 3    No           MD       Citation     1998 DODG DAKOTA
# 4    No           MD       Citation  2015 MINI COOPER 2S

# %%
# create a dataframe with the count of each violation by year/make/model.
tempdf = traffic.groupby('ymm').ymm.count().reset_index(name='ymm_count')
tempdf.sort_values('ymm_count', ascending=False).head(5) # sort the total violations by tear make and model
# Out:
#                          ymm  ymm_count
# 668             2016 TOYT TK          8
# 681            nan NONE NONE          7
# 353        2006 FORD MUSTANG          7
# 655      2015 MINI COOPER 2S          6
# 423  2007 NISS 350 Z TRICKED          5

# %%
tempdf = traffic[traffic.driver_state != 'MD'].groupby('driver_state').driver_state.count().reset_index(name='state_violations')
tempdf.sort_values('state_violations', ascending=False).head(5) # sort the total violations by tear make and model
# Out:
#   driver_state  state_violations
# 2           DC                28
# 9           VA                22
# 7           PA                 4
# 6           NY                 3
# 0           AK                 2

# %%
# create a dataframe with the count of each violation by year/make/model.
tempdf = traffic.groupby('violation_type').violation_type.count().reset_index(name='violation_count')
tempdf.sort_values('violation_count', ascending=False).head(5) # sort the total violations by tear make and model
# Out:
#   violation_type  violation_count
# 0       Citation              834
# 2        Warning              148
# 1          ESERO               17

# %% [markdown]
# 1. I will analyze the data by finding out which type of car has the most violations
#             The 2016 Toyota TK
# 2. Which state besides Maryland has the highest violations
#             Washingtnon DC
# 3. Which violation is most popular
#             Citation is the most popular vilation type.
